# %% [markdown]
# # 🔊 Amharic Text-to-Speech (TTS) Training on Google Colab (GPU)
# This notebook trains **Tacotron2** (acoustic model) and **HiFi-GAN** (vocoder) on Amharic speech data.

# %%
# 1. Check GPU
# !nvidia-smi

# %%
# 2. Install dependencies
# !pip install -q torch torchaudio datasets soundfile librosa tqdm pyyaml

# %%
# 3. Preprocess Data for TTS (22050Hz, Tacotron2 Mel format, G2P)
# !python src/data/preprocess_tts.py --input data/raw/all_metadata.csv --output data/processed/tts

# %%
# 4. Train Tacotron2 Acoustic Model
# !python src/training/train_tts.py --batch_size 16 --max_steps 100000

# %%
# 5. Train HiFi-GAN Vocoder
# !python src/training/train_hifigan.py
