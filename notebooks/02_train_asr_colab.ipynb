# %% [markdown]
# # 🎙️ Amharic Speech-to-Text (ASR) Training on Google Colab (GPU)
# This notebook trains an end-to-end **Conformer-CTC** model on open Amharic speech datasets from scratch.

# %%
# 1. Check GPU
# !nvidia-smi

# %%
# 2. Install dependencies
# !pip install -q torch torchaudio datasets transformers jiwer soundfile librosa tqdm pyyaml

# %%
# 3. Download FLEURS Amharic Dataset
# !python data/download_datasets.py --datasets fleurs --merge

# %%
# 4. Preprocess Data for ASR (16kHz, Log-Mel Spectrograms, Ethiopic Tokenization)
# !python src/data/preprocess_asr.py --input data/raw/all_metadata.csv --output data/processed/asr

# %%
# 5. Train Conformer-CTC ASR Model
# !python src/training/train_asr.py --batch_size 16 --max_steps 50000
